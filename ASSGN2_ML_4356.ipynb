# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
data = pd.read_csv("temperatures.csv")
data
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
data.shape
# Out:
# (117, 18)

# %%
 data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   YEAR     117 non-null    int64
#  1   JAN      117 non-null    float64
#  2   FEB      117 non-null    float64
#  3   MAR      117 non-null    float64
#  4   APR      117 non-null    float64
#  5   MAY      117 non-null    float64
#  6   JUN      117 non-null    float64
#  7   JUL      117 non-null    float64
#  8   AUG      117 non-null    float64
#  9   SEP      117 non-null    float64
#  10  OCT      117 non-null    float64
#  11  NOV      117 non-null    float64
#  12  DEC      117 non-null    float64
#  13  ANNUAL   117 non-null    float64
#  14  JAN-FEB  117 non-null    float64
#  15  MAR-MAY  117 non-null    float64
#  16  JUN-SEP  117 non-null    float64
#  17  OCT-DEC  117 non-null    float64
# dtypes: float64(17), int64(1)
# memory usage: 16.6 KB

# %%
data.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
#finding total number of null values in data
cnt = data.isnull().sum()
cnt
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# JAN-FEB    0
# MAR-MAY    0
# JUN-SEP    0
# OCT-DEC    0
# dtype: int64

# %%
data.corr()
# Out:
#              YEAR       JAN       FEB       MAR       APR       MAY       JUN  \
# YEAR     1.000000  0.575499  0.647066  0.553886  0.540662  0.407648  0.371840
# JAN      0.575499  1.000000  0.647017  0.457081  0.594674  0.365236  0.292855
# FEB      0.647066  0.647017  1.000000  0.589088  0.548803  0.377722  0.341302
# MAR      0.553886  0.457081  0.589088  1.000000  0.618621  0.387756  0.228349
# APR      0.540662  0.594674  0.548803  0.618621  1.000000  0.563317  0.299866
# MAY      0.407648  0.365236  0.377722  0.387756  0.563317  1.000000  0.274521
# JUN      0.371840  0.292855  0.341302  0.228349  0.299866  0.274521  1.000000
# JUL      0.478512  0.339337  0.418956  0.232647  0.286052  0.299072  0.480925
# AUG      0.654138  0.459944  0.503188  0.382344  0.490668  0.473171  0.504354
# SEP      0.664008  0.499764  0.472755  0.370066  0.437970  0.347289  0.305761
# OCT      0.589073  0.480695  0.466916  0.312226  0.473873  0.468993  0.380782
# ...

# %%
 #input variable
x = data['YEAR']

# %%
#output data
y = data['ANNUAL']

# %%
#plt.figure(figsize=(16,9))
plt.title('Temprature Range of India')
plt.xlabel('Year')
plt.ylabel('Annual Average Temprature')
plt.scatter(x,y)

# %%
X=data[['OCT-DEC']]
y=data['ANNUAL']

# %%
training_percentages = []
for i in range(1, 10):
    percentage = i / 10.0 
    training_percentages.append(percentage)

training_errors = []
testing_errors = []
for percentage in training_percentages:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1 - percentage, random_state=0)
    
    model = LinearRegression()
    model.fit(X_train, y_train)

    
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    training_sse = np.sum((y_train - y_train_pred) ** 2)
    testing_sse = np.sum((y_test - y_test_pred) ** 2)
    
    training_errors.append(training_sse)
    testing_errors.append(testing_sse)

plt.plot(training_percentages, training_errors, label="Training Error (SSE)")
plt.plot(training_percentages, testing_errors, label="Testing Error (SSE)")
plt.xlabel("Training Percentage")
plt.ylabel("SSE")
plt.legend()
plt.title("Training and Testing Error vs. Training Percentage")
plt.show()

# %%
## Model with highly corr and low Corr
data.corr()['ANNUAL'].sort_values()
# Out:
# JUN        0.520189
# JUL        0.588454
# MAY        0.609015
# MAR        0.689205
# SEP        0.730756
# JAN        0.749880
# AUG        0.755384
# OCT        0.768170
# APR        0.770596
# FEB        0.792541
# YEAR       0.801129
# JUN-SEP    0.810786
# NOV        0.812868
# DEC        0.843660
# JAN-FEB    0.849828
# MAR-MAY    0.853277
# OCT-DEC    0.897046
# ANNUAL     1.000000
# Name: ANNUAL, dtype: float64

# %%
## MODEL WITH HIGHLY CORRELATED
x1=data[['DEC']]
y1=data['ANNUAL']

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.10, random_state=0)

# %%
model.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y1_train_predicted=model.predict(x1_train)
y1_test_predicted=model.predict(x1_test)

# %%
plt.scatter(x1_test, y1_test, color='blue', label='Test Data')
plt.plot(x1_test, y1_test_predicted, color='red', label='Predicted Model')
plt.xlabel('DEC')
plt.ylabel('ANNUAL')
plt.title('Linear Regression Predicted Model')
plt.legend()
plt.show()

# %%
## Model with low corr feature
x=data[['JUN']]
y=data['ANNUAL']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=0)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_predicted=model.predict(x_train)
y_test_predicted=model.predict(x_test)
plt.scatter(x_test, y_test, color='blue', label='Test Data')
plt.plot(x_test, y_test_predicted, color='red', label='Predicted Model')
plt.xlabel('JUN')
plt.ylabel('ANNUAL')
plt.title('Linear Regression Predicted Model')
plt.legend()
plt.show()

# %%
mae = mean_absolute_error(y1_test,y1_test_predicted)
mae
# Out:
# 0.1996562626437409

# %%
#errors
print("Errors for highly correlated data(for training dataset)\n");
print("r2_score_dec_train",r2_score_dec_train);
print("mean_absolute_error_dec_train",mean_absolute_error_dec_train);
print("mean_squared_error_dec_train",mean_squared_error_dec_train);
print("root_mean_squared_error_dec_train",root_mean_squared_error_dec_train);
print("\n");

print("Errors for highly correlated data(for testing dataset)\n")
print("r2_score_dec_test",r2_score_dec_test);
print("mean_absolute_error_dec_test",mean_absolute_error_dec_test);
print("mean_squared_error_dec_test",mean_squared_error_dec_test);
print("root_mean_squared_error_dec_test",root_mean_squared_error_dec_test);
print("\n");

print("Errors for least correlated data(for training dataset)\n")
print("r2_score_jun_train",r2_score_jun_train);
print("mean_absolute_error_jun_train",mean_absolute_error_jun_train);
print("mean_squared_error_jun_train",mean_squared_error_jun_train);
print("root_mean_squared_error_jun_train",root_mean_squared_error_jun_train);
print("\n");

print("Errors for highly correlated data(for testing dataset)\n")
print("r2_score_jun_test",r2_score_jun_test);
print("mean_absolute_error_jun_test",mean_absolute_error_jun_test);
print("mean_squared_error_jun_test",mean_squared_error_jun_test);
print("root_mean_squared_error_jun_test",root_mean_squared_error_jun_test);
# Out:
# Errors for highly correlated data(for training dataset)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 #errors
#       2 print("Errors for highly correlated data(for training dataset)\n");
# ----> 3 print("r2_score_dec_train",r2_score_dec_train);
#       4 print("mean_absolute_error_dec_train",mean_absolute_error_dec_train);
#       5 print("mean_squared_error_dec_train",mean_squared_error_dec_train);
#
# NameError: name 'r2_score_dec_train' is not defined

# %%
#errors
print("Errors for highly correlated data(for training dataset)\n");
print("r2_score_dec_train",r2_score_dec_train);
print("mean_absolute_error_dec_train",mean_absolute_error_dec_train);
print("mean_squared_error_dec_train",mean_squared_error_dec_train);
print("root_mean_squared_error_dec_train",root_mean_squared_error_dec_train);
print("\n");

print("Errors for highly correlated data(for testing dataset)\n")
print("r2_score_dec_test",r2_score_dec_test);
print("mean_absolute_error_dec_test",mean_absolute_error_dec_test);
print("mean_squared_error_dec_test",mean_squared_error_dec_test);
print("root_mean_squared_error_dec_test",root_mean_squared_error_dec_test);
print("\n");

print("Errors for least correlated data(for training dataset)\n")
print("r2_score_jun_train",r2_score_jun_train);
print("mean_absolute_error_jun_train",mean_absolute_error_jun_train);
print("mean_squared_error_jun_train",mean_squared_error_jun_train);
print("root_mean_squared_error_jun_train",root_mean_squared_error_jun_train);
print("\n");

print("Errors for highly correlated data(for testing dataset)\n")
print("r2_score_jun_test",r2_score_jun_test);
print("mean_absolute_error_jun_test",mean_absolute_error_jun_test);
print("mean_squared_error_jun_test",mean_squared_error_jun_test);
print("root_mean_squared_error_jun_test",root_mean_squared_error_jun_test);
# Out:
# Errors for highly correlated data(for training dataset)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 #errors
#       2 print("Errors for highly correlated data(for training dataset)\n");
# ----> 3 print("r2_score_dec_train",r2_score_dec_train);
#       4 print("mean_absolute_error_dec_train",mean_absolute_error_dec_train);
#       5 print("mean_squared_error_dec_train",mean_squared_error_dec_train);
#
# NameError: name 'r2_score_dec_train' is not defined
